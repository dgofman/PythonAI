# %% [markdown]
# **hw1_exercise1.py**
#
# 1. Execute the code by clicking the "Run" button
# 2. Expand the Table Contexts menu
# 3. Click the Refresh button
# 4. Open slide_world.png file

# %%
import urllib.request
urllib.request.urlretrieve('https://raw.githubusercontent.com/dgofman/PythonAI/main/Homework5/hw5_exercise1.py', '/content/hw5_exercise1.py')

import hw5_exercise1 as hw
hw.main([None, 6, 50])
# Out:
# Direct Slides:
# [1 -> 2, 4 -> 6, 5 -> 6]
# Transition Slides:
# ['1 -> 3 -> 4', '1 -> 3 -> 5', '1 -> 3 -> 6']
# ['2 -> 3 -> 4', '2 -> 3 -> 5', '2 -> 3 -> 6']
